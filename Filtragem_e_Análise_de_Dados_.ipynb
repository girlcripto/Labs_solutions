# %% [markdown]
# <a href="https://colab.research.google.com/github/girlcripto/Labs_solutions/blob/master/Filtragem_e_Ana%CC%81lise_de_Dados_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![0a17c1e9-3a45-41b7-9837-49875a41ae75.png](data:image/png;base64,...)

# %% [markdown]
# > Adicionar aspas
#
# # Vamos Analisar Dados Ficticios para completar este desafio!
